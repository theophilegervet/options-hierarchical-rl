# %%
import gym
import numpy as np
import pickle
from model import Tabular, SoftmaxPolicy, EgreedyPolicy, \
    SigmoidTermination, IntraOptionQLearning, IntraOptionActionQLearning, \
    TerminationGradient, IntraOptionGradient
import random

discount = 0.99
lr_term = 0.25
lr_intra = 0.25
lr_critic = 0.5
epsilon = 0.01
temperature = 0.10
noptions = 4
nsteps = 1000

nruns = 1
nepisodes = 20000
verbose = True

rng = np.random.RandomState(1234)
env = gym.make('Fourrooms-v0')

#possible_next_goals = [68, 69, 70, 71, 72, 78, 79, 80, 81, 82, 88,
#                       89, 90, 91, 92, 93, 99, 100, 101, 102, 103]
#possible_next_goals = [0]
#goals = [62, 0, 40, 95, 62, 3, 97, 50] 
goals = [62] + random.sample(range(104), 19)

history = np.zeros((nruns, nepisodes, 2))

for run in range(nruns):
    features = Tabular(env.observation_space.n)
    nfeatures, nactions = len(features), env.action_space.n

    # The intra-option policies are linear-softmax functions
    option_policies = [SoftmaxPolicy(rng, nfeatures, nactions, temperature)
                       for _ in range(noptions)]
    
    # The termination function are linear-sigmoid functions
    option_terminations = [SigmoidTermination(rng, nfeatures) 
                           for _ in range(noptions)]

    # E-greedy policy over options
    policy_over_options = EgreedyPolicy(rng, nfeatures, noptions, epsilon)
    #policy_over_options = SoftmaxPolicy(rng, nfeatures, noptions, 0.001)

    # Different choices are possible for the critic. Here we learn an
    # option-value function and use the estimator for the values upon arrival
    critic = IntraOptionQLearning(discount, lr_critic, 
                                  option_terminations, policy_over_options.weights)

    # Learn Qomega separately
    action_weights = np.zeros((nfeatures, noptions, nactions))
    action_critic = IntraOptionActionQLearning(discount, lr_critic, 
                                               option_terminations, 
                                               action_weights, critic)

    # Improvement of the termination functions based on gradients
    termination_improvement = TerminationGradient(option_terminations, 
                                                  critic, lr_term)

    # Intra-option gradient improvement with critic estimator
    intraoption_improvement = IntraOptionGradient(option_policies, 
                                                  lr_intra)

    
    change_count = 1
    for episode in xrange(nepisodes):       
        if episode == 1000 * change_count:
            # Save current option policies and termination functions
            pickle.dump(option_policies, 
                        open("save/policies_{}.p".format(change_count), "wb"))
            pickle.dump(option_terminations, 
                        open("save/terminations_{}.p".format(change_count), "wb"))    
            pickle.dump(policy_over_options, 
                        open("save/mainpolicy_{}.p".format(change_count), "wb"))
            # Change goal
            #env.goal = rng.choice(possible_next_goals)
            env.goal = goals[change_count]
            print("New goal : ", env.tocell[env.goal])
            change_count += 1
            
        phi = features(env.reset())
        option = policy_over_options.sample(phi)
        action = option_policies[option].sample(phi)
        critic.start(phi, option)
        action_critic.start(phi, option, action)

        cumreward = 0.
        duration = 1
        option_switches = 0
        avgduration = 0.
        
        for step in range(nsteps):
            observation, reward, done, _ = env.step(action)
            phi = features(observation)

            # Termination might occur upon entering the new state
            if option_terminations[option].sample(phi):
                option = policy_over_options.sample(phi)
                option_switches += 1
                avgduration += (1. / option_switches) * \
                    (duration - avgduration)
                duration = 1

            action = option_policies[option].sample(phi)

            # Critic update
            update_target = critic.update(phi, option, reward, done)
            action_critic.update(phi, option, action, reward, done)

            if isinstance(option_policies[option], SoftmaxPolicy):
                # Intra-option policy update
                critic_feedback = action_critic.value(phi, option, action)
                critic_feedback -= critic.value(phi, option)
                intraoption_improvement.update(phi, option, action, 
                                               critic_feedback)
                # Termination update
                termination_improvement.update(phi, option)

            cumreward += reward
            duration += 1
            if done:
                break

        history[run, episode, 0] = step
        history[run, episode, 1] = avgduration
        if verbose:
            print('Run {} episode {} steps {} cumreward {} avg. duration \
                {} switches {}'.format(run, episode, step, cumreward, 
                                       avgduration, option_switches))
            
    pickle.dump(option_policies, 
                open("save/policies_{}.p".format(change_count), "wb"))
    pickle.dump(option_terminations, 
                open("save/terminations_{}.p".format(change_count), "wb"))    
    pickle.dump(policy_over_options, 
                open("save/mainpolicy_{}.p".format(change_count), "wb"))
# Out:
# [2017-11-15 12:12:51,926] Making new env: Fourrooms-v0
# Run 0 episode 0 steps 101 cumreward 1.0 avg. duration                 3.12765957447 switches 47
# Run 0 episode 1 steps 145 cumreward 1.0 avg. duration                 2.89473684211 switches 76
# Run 0 episode 2 steps 887 cumreward 1.0 avg. duration                 3.04861111111 switches 432
# Run 0 episode 3 steps 624 cumreward 1.0 avg. duration                 2.88787878788 switches 330
# Run 0 episode 4 steps 32 cumreward 1.0 avg. duration                 2.72222222222 switches 18
# Run 0 episode 5 steps 185 cumreward 1.0 avg. duration                 2.85 switches 100
# Run 0 episode 6 steps 857 cumreward 1.0 avg. duration                 2.97685185185 switches 432
# Run 0 episode 7 steps 7 cumreward 1.0 avg. duration                 2.4 switches 5
# Run 0 episode 8 steps 201 cumreward 1.0 avg. duration                 3.42168674699 switches 83
# Run 0 episode 9 steps 149 cumreward 1.0 avg. duration                 2.87341772152 switches 79
# Run 0 episode 10 steps 66 cumreward 1.0 avg. duration                 2.94117647059 switches 34
# Run 0 episode 11 steps 250 cumreward 1.0 avg. duration                 2.96031746032 switches 126
# Run 0 episode 12 steps 2 cumreward 1.0 avg. duration                 2.0 switches 1
# Run 0 episode 13 steps 2 cumreward 1.0 avg. duration                 2.0 switches 2
# Run 0 episode 14 steps 30 cumreward 1.0 avg. duration                 3.0 switches 15
# Run 0 episode 15 steps 90 cumreward 1.0 avg. duration                 2.95652173913 switches 46
# Run 0 episode 16 steps 163 cumreward 1.0 avg. duration                 3.13157894737 switches 76
# Run 0 episode 17 steps 89 cumreward 1.0 avg. duration                 2.87234042553 switches 47
# Run 0 episode 18 steps 134 cumreward 1.0 avg. duration                 3.0303030303 switches 66
# Run 0 episode 19 steps 384 cumreward 1.0 avg. duration                 2.95918367347 switches 196
# Run 0 episode 20 steps 3 cumreward 1.0 avg. duration                 2.0 switches 1
# Run 0 episode 21 steps 73 cumreward 1.0 avg. duration                 2.7380952381 switches 42
# Run 0 episode 22 steps 18 cumreward 1.0 avg. duration                 3.0 switches 9
# Run 0 episode 23 steps 38 cumreward 1.0 avg. duration                 3.0 switches 19
# Run 0 episode 24 steps 26 cumreward 1.0 avg. duration                 4.71428571429 switches 7
# Run 0 episode 25 steps 34 cumreward 1.0 avg. duration                 2.73684210526 switches 19
# Run 0 episode 26 steps 116 cumreward 1.0 avg. duration                 3.18867924528 switches 53
# Run 0 episode 27 steps 476 cumreward 1.0 avg. duration                 2.96265560166 switches 241
# Run 0 episode 28 steps 27 cumreward 1.0 avg. duration                 2.5625 switches 16
# Run 0 episode 29 steps 40 cumreward 1.0 avg. duration                 3.29411764706 switches 17
# Run 0 episode 30 steps 4 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 31 steps 47 cumreward 1.0 avg. duration                 2.74074074074 switches 27
# Run 0 episode 32 steps 19 cumreward 1.0 avg. duration                 3.11111111111 switches 9
# Run 0 episode 33 steps 0 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 34 steps 248 cumreward 1.0 avg. duration                 2.83703703704 switches 135
# Run 0 episode 35 steps 248 cumreward 1.0 avg. duration                 3.05833333333 switches 120
# Run 0 episode 36 steps 343 cumreward 1.0 avg. duration                 3.0 switches 171
# Run 0 episode 37 steps 10 cumreward 1.0 avg. duration                 2.25 switches 8
# Run 0 episode 38 steps 2 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 39 steps 31 cumreward 1.0 avg. duration                 2.82352941176 switches 17
# Run 0 episode 40 steps 73 cumreward 1.0 avg. duration                 3.21875 switches 32
# Run 0 episode 41 steps 10 cumreward 1.0 avg. duration                 2.66666666667 switches 6
# Run 0 episode 42 steps 178 cumreward 1.0 avg. duration                 2.9347826087 switches 92
# Run 0 episode 43 steps 111 cumreward 1.0 avg. duration                 3.17647058824 switches 51
# Run 0 episode 44 steps 735 cumreward 1.0 avg. duration                 2.95212765957 switches 376
# Run 0 episode 45 steps 45 cumreward 1.0 avg. duration                 2.83333333333 switches 24
# Run 0 episode 46 steps 213 cumreward 1.0 avg. duration                 2.89189189189 switches 111
# Run 0 episode 47 steps 7 cumreward 1.0 avg. duration                 3.0 switches 3
# Run 0 episode 48 steps 28 cumreward 1.0 avg. duration                 2.64285714286 switches 14
# Run 0 episode 49 steps 430 cumreward 1.0 avg. duration                 2.90265486726 switches 226
# Run 0 episode 50 steps 4 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 51 steps 41 cumreward 1.0 avg. duration                 3.15789473684 switches 19
# Run 0 episode 52 steps 6 cumreward 1.0 avg. duration                 3.0 switches 2
# Run 0 episode 53 steps 17 cumreward 1.0 avg. duration                 2.36363636364 switches 11
# Run 0 episode 54 steps 20 cumreward 1.0 avg. duration                 2.33333333333 switches 15
# Run 0 episode 55 steps 13 cumreward 1.0 avg. duration                 2.85714285714 switches 7
# Run 0 episode 56 steps 23 cumreward 1.0 avg. duration                 3.09090909091 switches 11
# Run 0 episode 57 steps 228 cumreward 1.0 avg. duration                 2.90756302521 switches 119
# Run 0 episode 58 steps 23 cumreward 1.0 avg. duration                 2.4375 switches 16
# Run 0 episode 59 steps 2 cumreward 1.0 avg. duration                 2.0 switches 1
# Run 0 episode 60 steps 264 cumreward 1.0 avg. duration                 2.85211267606 switches 142
# Run 0 episode 61 steps 100 cumreward 1.0 avg. duration                 3.27272727273 switches 44
# Run 0 episode 62 steps 5 cumreward 1.0 avg. duration                 1.75 switches 4
# Run 0 episode 63 steps 1 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 64 steps 4 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 65 steps 4 cumreward 1.0 avg. duration                 2.5 switches 2
# Run 0 episode 66 steps 26 cumreward 1.0 avg. duration                 2.85714285714 switches 14
# Run 0 episode 67 steps 13 cumreward 1.0 avg. duration                 2.5 switches 8
# Run 0 episode 68 steps 101 cumreward 1.0 avg. duration                 2.83636363636 switches 55
# Run 0 episode 69 steps 28 cumreward 1.0 avg. duration                 2.75 switches 16
# Run 0 episode 70 steps 12 cumreward 1.0 avg. duration                 3.2 switches 5
# Run 0 episode 71 steps 6 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 72 steps 9 cumreward 1.0 avg. duration                 2.33333333333 switches 6
# Run 0 episode 73 steps 48 cumreward 1.0 avg. duration                 2.5 switches 32
# Run 0 episode 74 steps 109 cumreward 1.0 avg. duration                 2.73015873016 switches 63
# Run 0 episode 75 steps 33 cumreward 1.0 avg. duration                 3.35714285714 switches 14
# Run 0 episode 76 steps 3 cumreward 1.0 avg. duration                 2.0 switches 3
# Run 0 episode 77 steps 130 cumreward 1.0 avg. duration                 3.08064516129 switches 62
# Run 0 episode 78 steps 13 cumreward 1.0 avg. duration                 2.18181818182 switches 11
# Run 0 episode 79 steps 3 cumreward 1.0 avg. duration                 4.0 switches 1
# Run 0 episode 80 steps 150 cumreward 1.0 avg. duration                 3.0985915493 switches 71
# Run 0 episode 81 steps 28 cumreward 1.0 avg. duration                 2.8 switches 15
# Run 0 episode 82 steps 57 cumreward 1.0 avg. duration                 2.9 switches 30
# Run 0 episode 83 steps 12 cumreward 1.0 avg. duration                 2.57142857143 switches 7
# Run 0 episode 84 steps 17 cumreward 1.0 avg. duration                 2.77777777778 switches 9
# Run 0 episode 85 steps 7 cumreward 1.0 avg. duration                 2.4 switches 5
# Run 0 episode 86 steps 4 cumreward 1.0 avg. duration                 2.5 switches 2
# Run 0 episode 87 steps 6 cumreward 1.0 avg. duration                 2.0 switches 6
# Run 0 episode 88 steps 32 cumreward 1.0 avg. duration                 2.66666666667 switches 18
# Run 0 episode 89 steps 17 cumreward 1.0 avg. duration                 2.30769230769 switches 13
# Run 0 episode 90 steps 1 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 91 steps 5 cumreward 1.0 avg. duration                 2.0 switches 3
# Run 0 episode 92 steps 20 cumreward 1.0 avg. duration                 3.0 switches 7
# Run 0 episode 93 steps 144 cumreward 1.0 avg. duration                 2.66279069767 switches 86
# Run 0 episode 94 steps 6 cumreward 1.0 avg. duration                 2.25 switches 4
# Run 0 episode 95 steps 139 cumreward 1.0 avg. duration                 2.95774647887 switches 71
# Run 0 episode 96 steps 15 cumreward 1.0 avg. duration                 2.66666666667 switches 9
# Run 0 episode 97 steps 23 cumreward 1.0 avg. duration                 2.91666666667 switches 12
# Run 0 episode 98 steps 152 cumreward 1.0 avg. duration                 3.02666666667 switches 75
# Run 0 episode 99 steps 10 cumreward 1.0 avg. duration                 2.28571428571 switches 7
# Run 0 episode 100 steps 5 cumreward 1.0 avg. duration                 2.0 switches 5
# Run 0 episode 101 steps 1 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 102 steps 6 cumreward 1.0 avg. duration                 4.0 switches 2
# Run 0 episode 103 steps 13 cumreward 1.0 avg. duration                 2.71428571429 switches 7
# Run 0 episode 104 steps 30 cumreward 1.0 avg. duration                 2.875 switches 16
# Run 0 episode 105 steps 15 cumreward 1.0 avg. duration                 3.14285714286 switches 7
# Run 0 episode 106 steps 24 cumreward 1.0 avg. duration                 3.18181818182 switches 11
# Run 0 episode 107 steps 61 cumreward 1.0 avg. duration                 3.06896551724 switches 29
# Run 0 episode 108 steps 2 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 109 steps 2 cumreward 1.0 avg. duration                 2.0 switches 2
# Run 0 episode 110 steps 5 cumreward 1.0 avg. duration                 2.25 switches 4
# Run 0 episode 111 steps 46 cumreward 1.0 avg. duration                 2.66666666667 switches 27
# Run 0 episode 112 steps 68 cumreward 1.0 avg. duration                 2.88888888889 switches 36
# Run 0 episode 113 steps 15 cumreward 1.0 avg. duration                 2.625 switches 8
# Run 0 episode 114 steps 19 cumreward 1.0 avg. duration                 2.38461538462 switches 13
# Run 0 episode 115 steps 48 cumreward 1.0 avg. duration                 3.0 switches 24
# Run 0 episode 116 steps 136 cumreward 1.0 avg. duration                 3.30508474576 switches 59
# Run 0 episode 117 steps 117 cumreward 1.0 avg. duration                 3.05263157895 switches 57
# Run 0 episode 118 steps 18 cumreward 1.0 avg. duration                 2.5 switches 12
# Run 0 episode 119 steps 22 cumreward 1.0 avg. duration                 2.69230769231 switches 13
# Run 0 episode 120 steps 61 cumreward 1.0 avg. duration                 2.93548387097 switches 31
# Run 0 episode 121 steps 17 cumreward 1.0 avg. duration                 2.54545454545 switches 11
# Run 0 episode 122 steps 4 cumreward 1.0 avg. duration                 1.8 switches 5
# Run 0 episode 123 steps 2 cumreward 1.0 avg. duration                 2.0 switches 1
# Run 0 episode 124 steps 85 cumreward 1.0 avg. duration                 2.84782608696 switches 46
# Run 0 episode 125 steps 1 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 126 steps 7 cumreward 1.0 avg. duration                 2.66666666667 switches 3
# Run 0 episode 127 steps 12 cumreward 1.0 avg. duration                 3.4 switches 5
# Run 0 episode 128 steps 10 cumreward 1.0 avg. duration                 2.11111111111 switches 9
# Run 0 episode 129 steps 28 cumreward 1.0 avg. duration                 2.625 switches 16
# Run 0 episode 130 steps 61 cumreward 1.0 avg. duration                 2.76470588235 switches 34
# Run 0 episode 131 steps 79 cumreward 1.0 avg. duration                 3.07894736842 switches 38
# Run 0 episode 132 steps 18 cumreward 1.0 avg. duration                 2.5 switches 12
# Run 0 episode 133 steps 39 cumreward 1.0 avg. duration                 3.16666666667 switches 18
# Run 0 episode 134 steps 55 cumreward 1.0 avg. duration                 2.66666666667 switches 33
# Run 0 episode 135 steps 9 cumreward 1.0 avg. duration                 2.0 switches 8
# Run 0 episode 136 steps 8 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 137 steps 38 cumreward 1.0 avg. duration                 2.72727272727 switches 22
# Run 0 episode 138 steps 14 cumreward 1.0 avg. duration                 2.16666666667 switches 12
# Run 0 episode 139 steps 21 cumreward 1.0 avg. duration                 2.30769230769 switches 13
# Run 0 episode 140 steps 7 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 141 steps 73 cumreward 1.0 avg. duration                 2.78048780488 switches 41
# Run 0 episode 142 steps 8 cumreward 1.0 avg. duration                 3.0 switches 4
# Run 0 episode 143 steps 10 cumreward 1.0 avg. duration                 3.66666666667 switches 3
# Run 0 episode 144 steps 12 cumreward 1.0 avg. duration                 3.4 switches 5
# Run 0 episode 145 steps 20 cumreward 1.0 avg. duration                 2.81818181818 switches 11
# Run 0 episode 146 steps 17 cumreward 1.0 avg. duration                 2.54545454545 switches 11
# Run 0 episode 147 steps 8 cumreward 1.0 avg. duration                 3.0 switches 4
# Run 0 episode 148 steps 9 cumreward 1.0 avg. duration                 3.25 switches 4
# Run 0 episode 149 steps 13 cumreward 1.0 avg. duration                 2.2 switches 10
# Run 0 episode 150 steps 10 cumreward 1.0 avg. duration                 2.42857142857 switches 7
# Run 0 episode 151 steps 17 cumreward 1.0 avg. duration                 2.66666666667 switches 9
# Run 0 episode 152 steps 5 cumreward 1.0 avg. duration                 2.66666666667 switches 3
# Run 0 episode 153 steps 4 cumreward 1.0 avg. duration                 2.0 switches 4
# Run 0 episode 154 steps 14 cumreward 1.0 avg. duration                 2.44444444444 switches 9
# Run 0 episode 155 steps 37 cumreward 1.0 avg. duration                 2.94736842105 switches 19
# Run 0 episode 156 steps 8 cumreward 1.0 avg. duration                 2.6 switches 5
# Run 0 episode 157 steps 5 cumreward 1.0 avg. duration                 2.0 switches 1
# Run 0 episode 158 steps 6 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 159 steps 3 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 160 steps 20 cumreward 1.0 avg. duration                 2.25 switches 16
# Run 0 episode 161 steps 79 cumreward 1.0 avg. duration                 2.925 switches 40
# Run 0 episode 162 steps 44 cumreward 1.0 avg. duration                 3.27777777778 switches 18
# Run 0 episode 163 steps 4 cumreward 1.0 avg. duration                 3.0 switches 2
# Run 0 episode 164 steps 2 cumreward 1.0 avg. duration                 3.0 switches 1
# Run 0 episode 165 steps 12 cumreward 1.0 avg. duration                 2.57142857143 switches 7
# Run 0 episode 166 steps 8 cumreward 1.0 avg. duration                 2.6 switches 5
# Run 0 episode 167 steps 1 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 168 steps 6 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 169 steps 5 cumreward 1.0 avg. duration                 2.0 switches 3
# Run 0 episode 170 steps 4 cumreward 1.0 avg. duration                 5.0 switches 1
# Run 0 episode 171 steps 4 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 172 steps 10 cumreward 1.0 avg. duration                 2.125 switches 8
# Run 0 episode 173 steps 19 cumreward 1.0 avg. duration                 2.58333333333 switches 12
# Run 0 episode 174 steps 7 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 175 steps 24 cumreward 1.0 avg. duration                 2.71428571429 switches 14
# Run 0 episode 176 steps 13 cumreward 1.0 avg. duration                 6.5 switches 2
# Run 0 episode 177 steps 14 cumreward 1.0 avg. duration                 2.75 switches 8
# Run 0 episode 178 steps 16 cumreward 1.0 avg. duration                 4.2 switches 5
# Run 0 episode 179 steps 9 cumreward 1.0 avg. duration                 2.125 switches 8
# Run 0 episode 180 steps 0 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 181 steps 34 cumreward 1.0 avg. duration                 3.0 switches 17
# Run 0 episode 182 steps 20 cumreward 1.0 avg. duration                 2.53846153846 switches 13
# Run 0 episode 183 steps 44 cumreward 1.0 avg. duration                 3.04761904762 switches 21
# Run 0 episode 184 steps 23 cumreward 1.0 avg. duration                 3.1 switches 10
# Run 0 episode 185 steps 15 cumreward 1.0 avg. duration                 2.55555555556 switches 9
# Run 0 episode 186 steps 37 cumreward 1.0 avg. duration                 2.94736842105 switches 19
# Run 0 episode 187 steps 9 cumreward 1.0 avg. duration                 3.66666666667 switches 3
# Run 0 episode 188 steps 22 cumreward 1.0 avg. duration                 2.83333333333 switches 12
# Run 0 episode 189 steps 3 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 190 steps 5 cumreward 1.0 avg. duration                 2.25 switches 4
# Run 0 episode 191 steps 29 cumreward 1.0 avg. duration                 2.6875 switches 16
# Run 0 episode 192 steps 8 cumreward 1.0 avg. duration                 3.66666666667 switches 3
# Run 0 episode 193 steps 7 cumreward 1.0 avg. duration                 3.0 switches 3
# Run 0 episode 194 steps 34 cumreward 1.0 avg. duration                 2.88888888889 switches 18
# Run 0 episode 195 steps 2 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 196 steps 16 cumreward 1.0 avg. duration                 2.77777777778 switches 9
# Run 0 episode 197 steps 21 cumreward 1.0 avg. duration                 2.90909090909 switches 11
# Run 0 episode 198 steps 0 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 199 steps 35 cumreward 1.0 avg. duration                 2.78947368421 switches 19
# Run 0 episode 200 steps 13 cumreward 1.0 avg. duration                 2.85714285714 switches 7
# Run 0 episode 201 steps 18 cumreward 1.0 avg. duration                 2.45454545455 switches 11
# Run 0 episode 202 steps 11 cumreward 1.0 avg. duration                 2.375 switches 8
# Run 0 episode 203 steps 28 cumreward 1.0 avg. duration                 3.0 switches 13
# Run 0 episode 204 steps 20 cumreward 1.0 avg. duration                 2.66666666667 switches 12
# Run 0 episode 205 steps 3 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 206 steps 13 cumreward 1.0 avg. duration                 2.625 switches 8
# Run 0 episode 207 steps 11 cumreward 1.0 avg. duration                 3.2 switches 5
# Run 0 episode 208 steps 11 cumreward 1.0 avg. duration                 4.66666666667 switches 3
# Run 0 episode 209 steps 16 cumreward 1.0 avg. duration                 3.28571428571 switches 7
# Run 0 episode 210 steps 3 cumreward 1.0 avg. duration                 3.0 switches 1
# Run 0 episode 211 steps 5 cumreward 1.0 avg. duration                 2.5 switches 2
# Run 0 episode 212 steps 12 cumreward 1.0 avg. duration                 2.375 switches 8
# Run 0 episode 213 steps 3 cumreward 1.0 avg. duration                 1.75 switches 4
# Run 0 episode 214 steps 22 cumreward 1.0 avg. duration                 4.0 switches 7
# Run 0 episode 215 steps 54 cumreward 1.0 avg. duration                 2.63636363636 switches 33
# Run 0 episode 216 steps 31 cumreward 1.0 avg. duration                 2.66666666667 switches 18
# Run 0 episode 217 steps 22 cumreward 1.0 avg. duration                 2.83333333333 switches 12
# Run 0 episode 218 steps 13 cumreward 1.0 avg. duration                 2.85714285714 switches 7
# Run 0 episode 219 steps 26 cumreward 1.0 avg. duration                 3.0 switches 13
# Run 0 episode 220 steps 8 cumreward 1.0 avg. duration                 3.5 switches 2
# Run 0 episode 221 steps 17 cumreward 1.0 avg. duration                 2.6 switches 10
# Run 0 episode 222 steps 19 cumreward 1.0 avg. duration                 2.8 switches 10
# Run 0 episode 223 steps 28 cumreward 1.0 avg. duration                 2.35 switches 20
# Run 0 episode 224 steps 14 cumreward 1.0 avg. duration                 2.22222222222 switches 9
# Run 0 episode 225 steps 4 cumreward 1.0 avg. duration                 3.0 switches 2
# Run 0 episode 226 steps 14 cumreward 1.0 avg. duration                 2.57142857143 switches 7
# Run 0 episode 227 steps 22 cumreward 1.0 avg. duration                 2.75 switches 12
# Run 0 episode 228 steps 5 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 229 steps 1 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 230 steps 11 cumreward 1.0 avg. duration                 3.33333333333 switches 3
# Run 0 episode 231 steps 6 cumreward 1.0 avg. duration                 2.0 switches 5
# Run 0 episode 232 steps 7 cumreward 1.0 avg. duration                 2.75 switches 4
# Run 0 episode 233 steps 3 cumreward 1.0 avg. duration                 2.5 switches 2
# Run 0 episode 234 steps 23 cumreward 1.0 avg. duration                 2.83333333333 switches 12
# Run 0 episode 235 steps 12 cumreward 1.0 avg. duration                 2.8 switches 5
# Run 0 episode 236 steps 12 cumreward 1.0 avg. duration                 2.57142857143 switches 7
# Run 0 episode 237 steps 22 cumreward 1.0 avg. duration                 3.2 switches 10
# Run 0 episode 238 steps 19 cumreward 1.0 avg. duration                 2.26666666667 switches 15
# Run 0 episode 239 steps 15 cumreward 1.0 avg. duration                 3.5 switches 6
# Run 0 episode 240 steps 10 cumreward 1.0 avg. duration                 2.75 switches 4
# Run 0 episode 241 steps 11 cumreward 1.0 avg. duration                 2.125 switches 8
# Run 0 episode 242 steps 10 cumreward 1.0 avg. duration                 2.11111111111 switches 9
# Run 0 episode 243 steps 15 cumreward 1.0 avg. duration                 2.36363636364 switches 11
# Run 0 episode 244 steps 18 cumreward 1.0 avg. duration                 3.33333333333 switches 6
# Run 0 episode 245 steps 67 cumreward 1.0 avg. duration                 3.12903225806 switches 31
# Run 0 episode 246 steps 14 cumreward 1.0 avg. duration                 2.71428571429 switches 7
# Run 0 episode 247 steps 15 cumreward 1.0 avg. duration                 3.8 switches 5
# Run 0 episode 248 steps 6 cumreward 1.0 avg. duration                 3.0 switches 1
# Run 0 episode 249 steps 7 cumreward 1.0 avg. duration                 2.16666666667 switches 6
# Run 0 episode 250 steps 23 cumreward 1.0 avg. duration                 3.0 switches 10
# Run 0 episode 251 steps 15 cumreward 1.0 avg. duration                 2.83333333333 switches 6
# Run 0 episode 252 steps 4 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 253 steps 8 cumreward 1.0 avg. duration                 2.4 switches 5
# Run 0 episode 254 steps 15 cumreward 1.0 avg. duration                 2.36363636364 switches 11
# Run 0 episode 255 steps 9 cumreward 1.0 avg. duration                 2.75 switches 4
# Run 0 episode 256 steps 3 cumreward 1.0 avg. duration                 1.75 switches 4
# Run 0 episode 257 steps 23 cumreward 1.0 avg. duration                 2.375 switches 16
# Run 0 episode 258 steps 16 cumreward 1.0 avg. duration                 2.55555555556 switches 9
# Run 0 episode 259 steps 3 cumreward 1.0 avg. duration                 3.0 switches 1
# Run 0 episode 260 steps 8 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 261 steps 38 cumreward 1.0 avg. duration                 3.11111111111 switches 18
# Run 0 episode 262 steps 10 cumreward 1.0 avg. duration                 2.6 switches 5
# Run 0 episode 263 steps 0 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 264 steps 25 cumreward 1.0 avg. duration                 2.47058823529 switches 17
# Run 0 episode 265 steps 20 cumreward 1.0 avg. duration                 2.33333333333 switches 15
# Run 0 episode 266 steps 11 cumreward 1.0 avg. duration                 2.57142857143 switches 7
# Run 0 episode 267 steps 10 cumreward 1.0 avg. duration                 2.25 switches 8
# Run 0 episode 268 steps 6 cumreward 1.0 avg. duration                 2.0 switches 6
# Run 0 episode 269 steps 14 cumreward 1.0 avg. duration                 2.2 switches 10
# Run 0 episode 270 steps 18 cumreward 1.0 avg. duration                 2.33333333333 switches 12
# Run 0 episode 271 steps 9 cumreward 1.0 avg. duration                 2.6 switches 5
# Run 0 episode 272 steps 17 cumreward 1.0 avg. duration                 3.125 switches 8
# Run 0 episode 273 steps 10 cumreward 1.0 avg. duration                 2.25 switches 8
# Run 0 episode 274 steps 17 cumreward 1.0 avg. duration                 2.33333333333 switches 12
# Run 0 episode 275 steps 2 cumreward 1.0 avg. duration                 3.0 switches 1
# Run 0 episode 276 steps 13 cumreward 1.0 avg. duration                 2.71428571429 switches 7
# Run 0 episode 277 steps 14 cumreward 1.0 avg. duration                 3.16666666667 switches 6
# Run 0 episode 278 steps 12 cumreward 1.0 avg. duration                 4.0 switches 4
# Run 0 episode 279 steps 11 cumreward 1.0 avg. duration                 2.83333333333 switches 6
# Run 0 episode 280 steps 13 cumreward 1.0 avg. duration                 3.4 switches 5
# Run 0 episode 281 steps 10 cumreward 1.0 avg. duration                 2.11111111111 switches 9
# Run 0 episode 282 steps 12 cumreward 1.0 avg. duration                 2.71428571429 switches 7
# Run 0 episode 283 steps 16 cumreward 1.0 avg. duration                 3.28571428571 switches 7
# Run 0 episode 284 steps 2 cumreward 1.0 avg. duration                 3.0 switches 1
# Run 0 episode 285 steps 6 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 286 steps 1 cumreward 1.0 avg. duration                 2.0 switches 1
# Run 0 episode 287 steps 5 cumreward 1.0 avg. duration                 3.5 switches 2
# Run 0 episode 288 steps 9 cumreward 1.0 avg. duration                 2.8 switches 5
# Run 0 episode 289 steps 10 cumreward 1.0 avg. duration                 2.28571428571 switches 7
# Run 0 episode 290 steps 17 cumreward 1.0 avg. duration                 4.2 switches 5
# Run 0 episode 291 steps 13 cumreward 1.0 avg. duration                 5.33333333333 switches 3
# Run 0 episode 292 steps 21 cumreward 1.0 avg. duration                 2.75 switches 12
# Run 0 episode 293 steps 11 cumreward 1.0 avg. duration                 2.42857142857 switches 7
# Run 0 episode 294 steps 18 cumreward 1.0 avg. duration                 3.57142857143 switches 7
# Run 0 episode 295 steps 13 cumreward 1.0 avg. duration                 2.625 switches 8
# Run 0 episode 296 steps 9 cumreward 1.0 avg. duration                 2.125 switches 8
# Run 0 episode 297 steps 19 cumreward 1.0 avg. duration                 2.9 switches 10
# Run 0 episode 298 steps 9 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 299 steps 6 cumreward 1.0 avg. duration                 2.0 switches 6
# Run 0 episode 300 steps 15 cumreward 1.0 avg. duration                 2.66666666667 switches 9
# Run 0 episode 301 steps 6 cumreward 1.0 avg. duration                 2.66666666667 switches 3
# Run 0 episode 302 steps 10 cumreward 1.0 avg. duration                 3.5 switches 4
# Run 0 episode 303 steps 12 cumreward 1.0 avg. duration                 2.71428571429 switches 7
# Run 0 episode 304 steps 12 cumreward 1.0 avg. duration                 2.28571428571 switches 7
# Run 0 episode 305 steps 11 cumreward 1.0 avg. duration                 2.25 switches 8
# Run 0 episode 306 steps 17 cumreward 1.0 avg. duration                 2.45454545455 switches 11
# Run 0 episode 307 steps 11 cumreward 1.0 avg. duration                 3.5 switches 4
# Run 0 episode 308 steps 19 cumreward 1.0 avg. duration                 2.9 switches 10
# Run 0 episode 309 steps 2 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 310 steps 18 cumreward 1.0 avg. duration                 3.125 switches 8
# Run 0 episode 311 steps 3 cumreward 1.0 avg. duration                 1.66666666667 switches 3
# Run 0 episode 312 steps 9 cumreward 1.0 avg. duration                 2.5 switches 6
# Run 0 episode 313 steps 14 cumreward 1.0 avg. duration                 3.4 switches 5
# Run 0 episode 314 steps 10 cumreward 1.0 avg. duration                 2.5 switches 6
# Run 0 episode 315 steps 11 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 316 steps 13 cumreward 1.0 avg. duration                 2.71428571429 switches 7
# Run 0 episode 317 steps 4 cumreward 1.0 avg. duration                 1.8 switches 5
# Run 0 episode 318 steps 7 cumreward 1.0 avg. duration                 2.4 switches 5
# Run 0 episode 319 steps 12 cumreward 1.0 avg. duration                 2.28571428571 switches 7
# Run 0 episode 320 steps 7 cumreward 1.0 avg. duration                 2.0 switches 7
# Run 0 episode 321 steps 4 cumreward 1.0 avg. duration                 2.0 switches 1
# Run 0 episode 322 steps 26 cumreward 1.0 avg. duration                 2.73333333333 switches 15
# Run 0 episode 323 steps 10 cumreward 1.0 avg. duration                 2.42857142857 switches 7
# Run 0 episode 324 steps 1 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 325 steps 6 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 326 steps 12 cumreward 1.0 avg. duration                 2.1 switches 10
# Run 0 episode 327 steps 8 cumreward 1.0 avg. duration                 3.0 switches 4
# Run 0 episode 328 steps 18 cumreward 1.0 avg. duration                 3.125 switches 8
# Run 0 episode 329 steps 7 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 330 steps 11 cumreward 1.0 avg. duration                 2.57142857143 switches 7
# Run 0 episode 331 steps 10 cumreward 1.0 avg. duration                 2.25 switches 8
# Run 0 episode 332 steps 7 cumreward 1.0 avg. duration                 3.5 switches 2
# Run 0 episode 333 steps 10 cumreward 1.0 avg. duration                 3.0 switches 5
# Run 0 episode 334 steps 7 cumreward 1.0 avg. duration                 2.4 switches 5
# Run 0 episode 335 steps 6 cumreward 1.0 avg. duration                 2.0 switches 3
# Run 0 episode 336 steps 12 cumreward 1.0 avg. duration                 2.5 switches 8
# Run 0 episode 337 steps 9 cumreward 1.0 avg. duration                 3.66666666667 switches 3
# Run 0 episode 338 steps 11 cumreward 1.0 avg. duration                 2.66666666667 switches 6
# Run 0 episode 339 steps 9 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 340 steps 44 cumreward 1.0 avg. duration                 2.95454545455 switches 22
# Run 0 episode 341 steps 14 cumreward 1.0 avg. duration                 2.625 switches 8
# Run 0 episode 342 steps 9 cumreward 1.0 avg. duration                 2.25 switches 4
# Run 0 episode 343 steps 18 cumreward 1.0 avg. duration                 2.63636363636 switches 11
# Run 0 episode 344 steps 14 cumreward 1.0 avg. duration                 2.16666666667 switches 12
# Run 0 episode 345 steps 9 cumreward 1.0 avg. duration                 3.25 switches 4
# Run 0 episode 346 steps 13 cumreward 1.0 avg. duration                 2.5 switches 8
# Run 0 episode 347 steps 6 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 348 steps 13 cumreward 1.0 avg. duration                 3.0 switches 6
# Run 0 episode 349 steps 12 cumreward 1.0 avg. duration                 2.66666666667 switches 6
# Run 0 episode 350 steps 6 cumreward 1.0 avg. duration                 2.66666666667 switches 3
# Run 0 episode 351 steps 9 cumreward 1.0 avg. duration                 2.33333333333 switches 6
# Run 0 episode 352 steps 3 cumreward 1.0 avg. duration                 2.0 switches 2
# Run 0 episode 353 steps 10 cumreward 1.0 avg. duration                 2.0 switches 7
# Run 0 episode 354 steps 10 cumreward 1.0 avg. duration                 3.5 switches 4
# Run 0 episode 355 steps 14 cumreward 1.0 avg. duration                 3.0 switches 5
# Run 0 episode 356 steps 5 cumreward 1.0 avg. duration                 4.0 switches 1
# Run 0 episode 357 steps 11 cumreward 1.0 avg. duration                 3.2 switches 5
# Run 0 episode 358 steps 13 cumreward 1.0 avg. duration                 2.44444444444 switches 9
# Run 0 episode 359 steps 15 cumreward 1.0 avg. duration                 2.875 switches 8
# Run 0 episode 360 steps 3 cumreward 1.0 avg. duration                 1.75 switches 4
# Run 0 episode 361 steps 2 cumreward 1.0 avg. duration                 3.0 switches 1
# Run 0 episode 362 steps 11 cumreward 1.0 avg. duration                 2.8 switches 5
# Run 0 episode 363 steps 6 cumreward 1.0 avg. duration                 4.0 switches 2
# Run 0 episode 364 steps 5 cumreward 1.0 avg. duration                 2.0 switches 5
# Run 0 episode 365 steps 0 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 366 steps 9 cumreward 1.0 avg. duration                 2.5 switches 6
# Run 0 episode 367 steps 9 cumreward 1.0 avg. duration                 2.5 switches 6
# Run 0 episode 368 steps 7 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 369 steps 9 cumreward 1.0 avg. duration                 2.75 switches 4
# Run 0 episode 370 steps 9 cumreward 1.0 avg. duration                 3.25 switches 4
# Run 0 episode 371 steps 18 cumreward 1.0 avg. duration                 2.7 switches 10
# Run 0 episode 372 steps 8 cumreward 1.0 avg. duration                 2.14285714286 switches 7
# Run 0 episode 373 steps 23 cumreward 1.0 avg. duration                 2.53333333333 switches 15
# Run 0 episode 374 steps 16 cumreward 1.0 avg. duration                 3.66666666667 switches 6
# Run 0 episode 375 steps 11 cumreward 1.0 avg. duration                 3.2 switches 5
# Run 0 episode 376 steps 16 cumreward 1.0 avg. duration                 3.14285714286 switches 7
# Run 0 episode 377 steps 9 cumreward 1.0 avg. duration                 7.0 switches 1
# Run 0 episode 378 steps 7 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 379 steps 4 cumreward 1.0 avg. duration                 2.0 switches 4
# Run 0 episode 380 steps 6 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 381 steps 2 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 382 steps 6 cumreward 1.0 avg. duration                 3.5 switches 2
# Run 0 episode 383 steps 1 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 384 steps 2 cumreward 1.0 avg. duration                 3.0 switches 1
# Run 0 episode 385 steps 9 cumreward 1.0 avg. duration                 3.25 switches 4
# Run 0 episode 386 steps 2 cumreward 1.0 avg. duration                 3.0 switches 1
# Run 0 episode 387 steps 11 cumreward 1.0 avg. duration                 2.66666666667 switches 6
# Run 0 episode 388 steps 7 cumreward 1.0 avg. duration                 3.0 switches 3
# Run 0 episode 389 steps 2 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 390 steps 3 cumreward 1.0 avg. duration                 2.5 switches 2
# Run 0 episode 391 steps 28 cumreward 1.0 avg. duration                 4.11111111111 switches 9
# Run 0 episode 392 steps 8 cumreward 1.0 avg. duration                 5.0 switches 2
# Run 0 episode 393 steps 6 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 394 steps 1 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 395 steps 12 cumreward 1.0 avg. duration                 3.0 switches 6
# Run 0 episode 396 steps 1 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 397 steps 2 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 398 steps 16 cumreward 1.0 avg. duration                 2.77777777778 switches 9
# Run 0 episode 399 steps 12 cumreward 1.0 avg. duration                 2.42857142857 switches 7
# Run 0 episode 400 steps 6 cumreward 1.0 avg. duration                 3.0 switches 3
# Run 0 episode 401 steps 12 cumreward 1.0 avg. duration                 2.33333333333 switches 9
# Run 0 episode 402 steps 12 cumreward 1.0 avg. duration                 2.33333333333 switches 9
# Run 0 episode 403 steps 0 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 404 steps 3 cumreward 1.0 avg. duration                 2.0 switches 3
# Run 0 episode 405 steps 4 cumreward 1.0 avg. duration                 2.0 switches 4
# Run 0 episode 406 steps 16 cumreward 1.0 avg. duration                 3.28571428571 switches 7
# Run 0 episode 407 steps 1 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 408 steps 10 cumreward 1.0 avg. duration                 2.42857142857 switches 7
# Run 0 episode 409 steps 14 cumreward 1.0 avg. duration                 2.85714285714 switches 7
# Run 0 episode 410 steps 3 cumreward 1.0 avg. duration                 4.0 switches 1
# Run 0 episode 411 steps 2 cumreward 1.0 avg. duration                 3.0 switches 1
# Run 0 episode 412 steps 6 cumreward 1.0 avg. duration                 2.0 switches 6
# Run 0 episode 413 steps 7 cumreward 1.0 avg. duration                 3.0 switches 2
# Run 0 episode 414 steps 16 cumreward 1.0 avg. duration                 2.45454545455 switches 11
# Run 0 episode 415 steps 21 cumreward 1.0 avg. duration                 2.81818181818 switches 11
# Run 0 episode 416 steps 5 cumreward 1.0 avg. duration                 2.66666666667 switches 3
# Run 0 episode 417 steps 6 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 418 steps 20 cumreward 1.0 avg. duration                 2.53846153846 switches 13
# Run 0 episode 419 steps 16 cumreward 1.0 avg. duration                 2.66666666667 switches 9
# Run 0 episode 420 steps 8 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 421 steps 10 cumreward 1.0 avg. duration                 2.42857142857 switches 7
# Run 0 episode 422 steps 6 cumreward 1.0 avg. duration                 4.0 switches 2
# Run 0 episode 423 steps 13 cumreward 1.0 avg. duration                 2.22222222222 switches 9
# Run 0 episode 424 steps 15 cumreward 1.0 avg. duration                 3.16666666667 switches 6
# Run 0 episode 425 steps 8 cumreward 1.0 avg. duration                 2.6 switches 5
# Run 0 episode 426 steps 4 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 427 steps 5 cumreward 1.0 avg. duration                 3.0 switches 2
# Run 0 episode 428 steps 5 cumreward 1.0 avg. duration                 3.0 switches 2
# Run 0 episode 429 steps 13 cumreward 1.0 avg. duration                 2.625 switches 8
# Run 0 episode 430 steps 22 cumreward 1.0 avg. duration                 2.83333333333 switches 12
# Run 0 episode 431 steps 6 cumreward 1.0 avg. duration                 3.0 switches 3
# Run 0 episode 432 steps 15 cumreward 1.0 avg. duration                 2.4 switches 10
# Run 0 episode 433 steps 7 cumreward 1.0 avg. duration                 3.5 switches 2
# Run 0 episode 434 steps 5 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 435 steps 10 cumreward 1.0 avg. duration                 3.25 switches 4
# Run 0 episode 436 steps 7 cumreward 1.0 avg. duration                 3.33333333333 switches 3
# Run 0 episode 437 steps 9 cumreward 1.0 avg. duration                 2.125 switches 8
# Run 0 episode 438 steps 12 cumreward 1.0 avg. duration                 2.71428571429 switches 7
# Run 0 episode 439 steps 10 cumreward 1.0 avg. duration                 3.0 switches 5
# Run 0 episode 440 steps 7 cumreward 1.0 avg. duration                 2.75 switches 4
# Run 0 episode 441 steps 1 cumreward 1.0 avg. duration                 2.0 switches 1
# Run 0 episode 442 steps 14 cumreward 1.0 avg. duration                 3.33333333333 switches 6
# Run 0 episode 443 steps 6 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 444 steps 13 cumreward 1.0 avg. duration                 2.3 switches 10
# Run 0 episode 445 steps 3 cumreward 1.0 avg. duration                 2.0 switches 2
# Run 0 episode 446 steps 10 cumreward 1.0 avg. duration                 3.66666666667 switches 3
# Run 0 episode 447 steps 15 cumreward 1.0 avg. duration                 2.66666666667 switches 9
# Run 0 episode 448 steps 5 cumreward 1.0 avg. duration                 2.0 switches 3
# Run 0 episode 449 steps 9 cumreward 1.0 avg. duration                 2.75 switches 4
# Run 0 episode 450 steps 7 cumreward 1.0 avg. duration                 4.5 switches 2
# Run 0 episode 451 steps 13 cumreward 1.0 avg. duration                 3.0 switches 6
# Run 0 episode 452 steps 6 cumreward 1.0 avg. duration                 4.0 switches 2
# Run 0 episode 453 steps 7 cumreward 1.0 avg. duration                 2.75 switches 4
# Run 0 episode 454 steps 3 cumreward 1.0 avg. duration                 2.0 switches 3
# Run 0 episode 455 steps 14 cumreward 1.0 avg. duration                 2.75 switches 8
# Run 0 episode 456 steps 14 cumreward 1.0 avg. duration                 2.4 switches 10
# Run 0 episode 457 steps 11 cumreward 1.0 avg. duration                 1.66666666667 switches 3
# Run 0 episode 458 steps 9 cumreward 1.0 avg. duration                 2.33333333333 switches 6
# Run 0 episode 459 steps 1 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 460 steps 5 cumreward 1.0 avg. duration                 2.0 switches 4
# Run 0 episode 461 steps 4 cumreward 1.0 avg. duration                 2.5 switches 2
# Run 0 episode 462 steps 7 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 463 steps 9 cumreward 1.0 avg. duration                 2.28571428571 switches 7
# Run 0 episode 464 steps 15 cumreward 1.0 avg. duration                 2.875 switches 8
# Run 0 episode 465 steps 2 cumreward 1.0 avg. duration                 1.66666666667 switches 3
# Run 0 episode 466 steps 10 cumreward 1.0 avg. duration                 3.5 switches 4
# Run 0 episode 467 steps 8 cumreward 1.0 avg. duration                 2.33333333333 switches 6
# Run 0 episode 468 steps 14 cumreward 1.0 avg. duration                 2.33333333333 switches 9
# Run 0 episode 469 steps 4 cumreward 1.0 avg. duration                 2.0 switches 1
# Run 0 episode 470 steps 4 cumreward 1.0 avg. duration                 3.0 switches 2
# Run 0 episode 471 steps 18 cumreward 1.0 avg. duration                 3.0 switches 7
# Run 0 episode 472 steps 10 cumreward 1.0 avg. duration                 3.0 switches 5
# Run 0 episode 473 steps 2 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 474 steps 13 cumreward 1.0 avg. duration                 2.33333333333 switches 9
# Run 0 episode 475 steps 4 cumreward 1.0 avg. duration                 3.0 switches 2
# Run 0 episode 476 steps 3 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 477 steps 6 cumreward 1.0 avg. duration                 2.25 switches 4
# Run 0 episode 478 steps 22 cumreward 1.0 avg. duration                 2.83333333333 switches 12
# Run 0 episode 479 steps 9 cumreward 1.0 avg. duration                 2.5 switches 6
# Run 0 episode 480 steps 13 cumreward 1.0 avg. duration                 2.2 switches 10
# Run 0 episode 481 steps 10 cumreward 1.0 avg. duration                 2.16666666667 switches 6
# Run 0 episode 482 steps 2 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 483 steps 0 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 484 steps 5 cumreward 1.0 avg. duration                 2.0 switches 5
# Run 0 episode 485 steps 3 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 486 steps 3 cumreward 1.0 avg. duration                 2.0 switches 3
# Run 0 episode 487 steps 11 cumreward 1.0 avg. duration                 2.375 switches 8
# Run 0 episode 488 steps 1 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 489 steps 1 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 490 steps 18 cumreward 1.0 avg. duration                 2.8 switches 10
# Run 0 episode 491 steps 8 cumreward 1.0 avg. duration                 2.66666666667 switches 3
# Run 0 episode 492 steps 4 cumreward 1.0 avg. duration                 0.0 switches 0
# Run 0 episode 493 steps 4 cumreward 1.0 avg. duration                 1.75 switches 4
# Run 0 episode 494 steps 14 cumreward 1.0 avg. duration                 3.8 switches 5
# Run 0 episode 495 steps 10 cumreward 1.0 avg. duration                 3.66666666667 switches 3
# Run 0 episode 496 steps 4 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 497 steps 10 cumreward 1.0 avg. duration                 2.125 switches 8
# Run 0 episode 498 steps 8 cumreward 1.0 avg. duration                 2.33333333333 switches 6
# Run 0 episode 499 steps 8 cumreward 1.0 avg. duration                 3.66666666667 switches 3
# Run 0 episode 500 steps 11 cumreward 1.0 avg. duration                 2.5 switches 6
# Run 0 episode 501 steps 6 cumreward 1.0 avg. duration                 2.0 switches 4
# Run 0 episode 502 steps 10 cumreward 1.0 avg. duration                 3.25 switches 4
# Run 0 episode 503 steps 10 cumreward 1.0 avg. duration                 4.0 switches 3
# Run 0 episode 504 steps 2 cumreward 1.0 avg. duration                 1.66666666667 switches 3
# Run 0 episode 505 steps 12 cumreward 1.0 avg. duration                 3.4 switches 5
# Run 0 episode 506 steps 12 cumreward 1.0 avg. duration                 2.83333333333 switches 6
# Run 0 episode 507 steps 8 cumreward 1.0 avg. duration                 2.33333333333 switches 6
# Run 0 episode 508 steps 8 cumreward 1.0 avg. duration                 3.0 switches 4
# Run 0 episode 509 steps 15 cumreward 1.0 avg. duration                 3.14285714286 switches 7
# Run 0 episode 510 steps 8 cumreward 1.0 avg. duration                 2.6 switches 5
# Run 0 episode 511 steps 20 cumreward 1.0 avg. duration                 3.22222222222 switches 9
# Run 0 episode 512 steps 9 cumreward 1.0 avg. duration                 2.5 switches 6
# Run 0 episode 513 steps 8 cumreward 1.0 avg. duration                 2.33333333333 switches 6
# Run 0 episode 514 steps 5 cumreward 1.0 avg. duration                 2.0 switches 3
# Run 0 episode 515 steps 10 cumreward 1.0 avg. duration                 2.42857142857 switches 7
# Run 0 episode 516 steps 11 cumreward 1.0 avg. duration                 2.375 switches 8
# Run 0 episode 517 steps 15 cumreward 1.0 avg. duration                 2.4 switches 10
# Run 0 episode 518 steps 3 cumreward 1.0 avg. duration                 2.0 switches 3
# Run 0 episode 519 steps 12 cumreward 1.0 avg. duration                 3.4 switches 5
# Run 0 episode 520 steps 7 cumreward 1.0 avg. duration                 2.75 switches 4
# Run 0 episode 521 steps 11 cumreward 1.0 avg. duration                 2.22222222222 switches 9
# Run 0 episode 522 steps 10 cumreward 1.0 avg. duration                 2.5 switches 6
# Run 0 episode 523 steps 18 cumreward 1.0 avg. duration                 2.7 switches 10
# Run 0 episode 524 steps 12 cumreward 1.0 avg. duration                 2.5 switches 8
# Run 0 episode 525 steps 15 cumreward 1.0 avg. duration                 2.875 switches 8
# Run 0 episode 526 steps 10 cumreward 1.0 avg. duration                 4.33333333333 switches 3
# Run 0 episode 527 steps 11 cumreward 1.0 avg. duration                 2.66666666667 switches 6
# Run 0 episode 528 steps 7 cumreward 1.0 avg. duration                 2.75 switches 4
# Run 0 episode 529 steps 4 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 530 steps 28 cumreward 1.0 avg. duration                 3.0 switches 14
# ...
# Run 0 episode 7829 steps 31 cumreward 1.0 avg. duration                 2.29166666667 switches 24
# Run 0 episode 7830 steps 22 cumreward 1.0 avg. duration                 2.1 switches 20
# Run 0 episode 7831 steps 11 cumreward 1.0 avg. duration                 2.22222222222 switches 9
# Run 0 episode 7832 steps 18 cumreward 1.0 avg. duration                 2.5 switches 12
# Run 0 episode 7833 steps 8 cumreward 1.0 avg. duration                 2.33333333333 switches 6
# Run 0 episode 7834 steps 10 cumreward 1.0 avg. duration                 2.11111111111 switches 9
# Run 0 episode 7835 steps 33 cumreward 1.0 avg. duration                 2.57142857143 switches 21
# Run 0 episode 7836 steps 23 cumreward 1.0 avg. duration                 2.53333333333 switches 15
# Run 0 episode 7837 steps 6 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 7838 steps 3 cumreward 1.0 avg. duration                 2.0 switches 2
# Run 0 episode 7839 steps 50 cumreward 1.0 avg. duration                 2.31578947368 switches 38
# Run 0 episode 7840 steps 43 cumreward 1.0 avg. duration                 2.65384615385 switches 26
# Run 0 episode 7841 steps 15 cumreward 1.0 avg. duration                 2.25 switches 12
# Run 0 episode 7842 steps 29 cumreward 1.0 avg. duration                 2.31818181818 switches 22
# Run 0 episode 7843 steps 20 cumreward 1.0 avg. duration                 2.17647058824 switches 17
# Run 0 episode 7844 steps 14 cumreward 1.0 avg. duration                 2.16666666667 switches 12
# Run 0 episode 7845 steps 11 cumreward 1.0 avg. duration                 2.0 switches 11
# Run 0 episode 7846 steps 41 cumreward 1.0 avg. duration                 2.57692307692 switches 26
# Run 0 episode 7847 steps 42 cumreward 1.0 avg. duration                 2.61538461538 switches 26
# Run 0 episode 7848 steps 12 cumreward 1.0 avg. duration                 2.5 switches 8
# Run 0 episode 7849 steps 27 cumreward 1.0 avg. duration                 2.44444444444 switches 18
# Run 0 episode 7850 steps 23 cumreward 1.0 avg. duration                 2.1 switches 20
# Run 0 episode 7851 steps 5 cumreward 1.0 avg. duration                 2.66666666667 switches 3
# Run 0 episode 7852 steps 41 cumreward 1.0 avg. duration                 2.32258064516 switches 31
# Run 0 episode 7853 steps 6 cumreward 1.0 avg. duration                 2.25 switches 4
# Run 0 episode 7854 steps 20 cumreward 1.0 avg. duration                 2.1875 switches 16
# Run 0 episode 7855 steps 1 cumreward 1.0 avg. duration                 1.5 switches 2
# Run 0 episode 7856 steps 10 cumreward 1.0 avg. duration                 2.25 switches 8
# Run 0 episode 7857 steps 14 cumreward 1.0 avg. duration                 2.75 switches 8
# Run 0 episode 7858 steps 38 cumreward 1.0 avg. duration                 2.46153846154 switches 26
# Run 0 episode 7859 steps 8 cumreward 1.0 avg. duration                 2.14285714286 switches 7
# Run 0 episode 7860 steps 75 cumreward 1.0 avg. duration                 2.5625 switches 48
# Run 0 episode 7861 steps 13 cumreward 1.0 avg. duration                 2.625 switches 8
# Run 0 episode 7862 steps 36 cumreward 1.0 avg. duration                 2.44 switches 25
# Run 0 episode 7863 steps 25 cumreward 1.0 avg. duration                 2.25 switches 20
# Run 0 episode 7864 steps 21 cumreward 1.0 avg. duration                 2.5 switches 14
# Run 0 episode 7865 steps 9 cumreward 1.0 avg. duration                 2.125 switches 8
# Run 0 episode 7866 steps 28 cumreward 1.0 avg. duration                 2.55555555556 switches 18
# Run 0 episode 7867 steps 32 cumreward 1.0 avg. duration                 2.23076923077 switches 26
# Run 0 episode 7868 steps 22 cumreward 1.0 avg. duration                 2.375 switches 16
# Run 0 episode 7869 steps 20 cumreward 1.0 avg. duration                 2.66666666667 switches 12
# Run 0 episode 7870 steps 6 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 7871 steps 35 cumreward 1.0 avg. duration                 2.88888888889 switches 18
# Run 0 episode 7872 steps 34 cumreward 1.0 avg. duration                 2.25925925926 switches 27
# Run 0 episode 7873 steps 8 cumreward 1.0 avg. duration                 2.14285714286 switches 7
# Run 0 episode 7874 steps 18 cumreward 1.0 avg. duration                 2.8 switches 10
# Run 0 episode 7875 steps 5 cumreward 1.0 avg. duration                 2.0 switches 5
# Run 0 episode 7876 steps 5 cumreward 1.0 avg. duration                 2.0 switches 5
# Run 0 episode 7877 steps 46 cumreward 1.0 avg. duration                 2.53333333333 switches 30
# Run 0 episode 7878 steps 17 cumreward 1.0 avg. duration                 2.14285714286 switches 14
# Run 0 episode 7879 steps 6 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 7880 steps 15 cumreward 1.0 avg. duration                 2.875 switches 8
# Run 0 episode 7881 steps 15 cumreward 1.0 avg. duration                 2.66666666667 switches 9
# Run 0 episode 7882 steps 18 cumreward 1.0 avg. duration                 2.38461538462 switches 13
# Run 0 episode 7883 steps 45 cumreward 1.0 avg. duration                 2.32352941176 switches 34
# Run 0 episode 7884 steps 14 cumreward 1.0 avg. duration                 2.16666666667 switches 12
# Run 0 episode 7885 steps 30 cumreward 1.0 avg. duration                 2.30434782609 switches 23
# Run 0 episode 7886 steps 12 cumreward 1.0 avg. duration                 2.33333333333 switches 9
# Run 0 episode 7887 steps 5 cumreward 1.0 avg. duration                 2.0 switches 4
# Run 0 episode 7888 steps 23 cumreward 1.0 avg. duration                 2.76923076923 switches 13
# Run 0 episode 7889 steps 26 cumreward 1.0 avg. duration                 2.3 switches 20
# Run 0 episode 7890 steps 26 cumreward 1.0 avg. duration                 2.44444444444 switches 18
# Run 0 episode 7891 steps 14 cumreward 1.0 avg. duration                 3.0 switches 7
# Run 0 episode 7892 steps 29 cumreward 1.0 avg. duration                 2.52631578947 switches 19
# Run 0 episode 7893 steps 28 cumreward 1.0 avg. duration                 2.21739130435 switches 23
# Run 0 episode 7894 steps 26 cumreward 1.0 avg. duration                 2.2380952381 switches 21
# Run 0 episode 7895 steps 38 cumreward 1.0 avg. duration                 2.72727272727 switches 22
# Run 0 episode 7896 steps 27 cumreward 1.0 avg. duration                 2.58823529412 switches 17
# Run 0 episode 7897 steps 30 cumreward 1.0 avg. duration                 2.25 switches 24
# Run 0 episode 7898 steps 10 cumreward 1.0 avg. duration                 2.0 switches 10
# Run 0 episode 7899 steps 10 cumreward 1.0 avg. duration                 2.66666666667 switches 6
# Run 0 episode 7900 steps 5 cumreward 1.0 avg. duration                 1.75 switches 4
# Run 0 episode 7901 steps 33 cumreward 1.0 avg. duration                 2.4347826087 switches 23
# Run 0 episode 7902 steps 20 cumreward 1.0 avg. duration                 2.25 switches 16
# Run 0 episode 7903 steps 14 cumreward 1.0 avg. duration                 2.16666666667 switches 12
# Run 0 episode 7904 steps 7 cumreward 1.0 avg. duration                 2.4 switches 5
# Run 0 episode 7905 steps 25 cumreward 1.0 avg. duration                 2.38888888889 switches 18
# Run 0 episode 7906 steps 16 cumreward 1.0 avg. duration                 2.6 switches 10
# Run 0 episode 7907 steps 4 cumreward 1.0 avg. duration                 2.33333333333 switches 3
# Run 0 episode 7908 steps 21 cumreward 1.0 avg. duration                 2.75 switches 12
# Run 0 episode 7909 steps 33 cumreward 1.0 avg. duration                 3.35714285714 switches 14
# Run 0 episode 7910 steps 18 cumreward 1.0 avg. duration                 2.2 switches 15
# Run 0 episode 7911 steps 27 cumreward 1.0 avg. duration                 2.8 switches 15
# Run 0 episode 7912 steps 6 cumreward 1.0 avg. duration                 2.2 switches 5
# Run 0 episode 7913 steps 16 cumreward 1.0 avg. duration                 2.23076923077 switches 13
# Run 0 episode 7914 steps 13 cumreward 1.0 avg. duration                 2.5 switches 8
# Run 0 episode 7915 steps 69 cumreward 1.0 avg. duration                 2.4375 switches 48
# Run 0 episode 7916 steps 47 cumreward 1.0 avg. duration                 2.42424242424 switches 33
# Run 0 episode 7917 steps 19 cumreward 1.0 avg. duration                 2.46153846154 switches 13
# Run 0 episode 7918 steps 16 cumreward 1.0 avg. duration                 2.33333333333 switches 12
# Run 0 episode 7919 steps 35 cumreward 1.0 avg. duration                 2.34615384615 switches 26
# Run 0 episode 7920 steps 49 cumreward 1.0 avg. duration                 2.63333333333 switches 30
# Run 0 episode 7921 steps 89 cumreward 1.0 avg. duration                 2.58928571429 switches 56
# Run 0 episode 7922 steps 20 cumreward 1.0 avg. duration                 2.11111111111 switches 18
# Run 0 episode 7923 steps 18 cumreward 1.0 avg. duration                 2.05882352941 switches 17
# Run 0 episode 7924 steps 10 cumreward 1.0 avg. duration                 2.11111111111 switches 9
# Run 0 episode 7925 steps 19 cumreward 1.0 avg. duration                 2.1875 switches 16
# Run 0 episode 7926 steps 4 cumreward 1.0 avg. duration                 3.0 switches 2
# Run 0 episode 7927 steps 29 cumreward 1.0 avg. duration                 2.52631578947 switches 19
# Run 0 episode 7928 steps 56 cumreward 1.0 avg. duration                 2.4 switches 40
# Run 0 episode 7929 steps 41 cumreward 1.0 avg. duration                 2.51851851852 switches 27
# Run 0 episode 7930 steps 5 cumreward 1.0 avg. duration                 2.25 switches 4
# Run 0 episode 7931 steps 20 cumreward 1.0 avg. duration                 2.33333333333 switches 15
# Run 0 episode 7932 steps 6 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 7933 steps 43 cumreward 1.0 avg. duration                 2.48275862069 switches 29
# Run 0 episode 7934 steps 31 cumreward 1.0 avg. duration                 2.29166666667 switches 24
# Run 0 episode 7935 steps 15 cumreward 1.0 avg. duration                 2.875 switches 8
# Run 0 episode 7936 steps 9 cumreward 1.0 avg. duration                 2.28571428571 switches 7
# Run 0 episode 7937 steps 16 cumreward 1.0 avg. duration                 2.23076923077 switches 13
# Run 0 episode 7938 steps 55 cumreward 1.0 avg. duration                 2.25 switches 44
# Run 0 episode 7939 steps 17 cumreward 1.0 avg. duration                 2.41666666667 switches 12
# Run 0 episode 7940 steps 15 cumreward 1.0 avg. duration                 2.5 switches 10
# Run 0 episode 7941 steps 29 cumreward 1.0 avg. duration                 2.26086956522 switches 23
# Run 0 episode 7942 steps 24 cumreward 1.0 avg. duration                 2.26315789474 switches 19
# Run 0 episode 7943 steps 5 cumreward 1.0 avg. duration                 2.25 switches 4
# Run 0 episode 7944 steps 7 cumreward 1.0 avg. duration                 2.0 switches 6
# Run 0 episode 7945 steps 14 cumreward 1.0 avg. duration                 2.4 switches 10
# Run 0 episode 7946 steps 37 cumreward 1.0 avg. duration                 2.68181818182 switches 22
# Run 0 episode 7947 steps 21 cumreward 1.0 avg. duration                 2.5 switches 14
# Run 0 episode 7948 steps 2 cumreward 1.0 avg. duration                 1.66666666667 switches 3
# Run 0 episode 7949 steps 10 cumreward 1.0 avg. duration                 2.25 switches 8
# Run 0 episode 7950 steps 0 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 7951 steps 11 cumreward 1.0 avg. duration                 2.57142857143 switches 7
# Run 0 episode 7952 steps 8 cumreward 1.0 avg. duration                 2.14285714286 switches 7
# Run 0 episode 7953 steps 27 cumreward 1.0 avg. duration                 2.17391304348 switches 23
# Run 0 episode 7954 steps 55 cumreward 1.0 avg. duration                 2.34146341463 switches 41
# Run 0 episode 7955 steps 29 cumreward 1.0 avg. duration                 2.38095238095 switches 21
# Run 0 episode 7956 steps 2 cumreward 1.0 avg. duration                 2.0 switches 2
# Run 0 episode 7957 steps 62 cumreward 1.0 avg. duration                 2.40909090909 switches 44
# Run 0 episode 7958 steps 32 cumreward 1.0 avg. duration                 2.33333333333 switches 24
# Run 0 episode 7959 steps 11 cumreward 1.0 avg. duration                 2.42857142857 switches 7
# Run 0 episode 7960 steps 6 cumreward 1.0 avg. duration                 2.5 switches 4
# Run 0 episode 7961 steps 8 cumreward 1.0 avg. duration                 2.0 switches 8
# Run 0 episode 7962 steps 18 cumreward 1.0 avg. duration                 2.63636363636 switches 11
# Run 0 episode 7963 steps 8 cumreward 1.0 avg. duration                 2.0 switches 8
# Run 0 episode 7964 steps 9 cumreward 1.0 avg. duration                 2.0 switches 9
# Run 0 episode 7965 steps 27 cumreward 1.0 avg. duration                 2.5 switches 18
# Run 0 episode 7966 steps 0 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 7967 steps 11 cumreward 1.0 avg. duration                 2.22222222222 switches 9
# Run 0 episode 7968 steps 22 cumreward 1.0 avg. duration                 2.46666666667 switches 15
# Run 0 episode 7969 steps 35 cumreward 1.0 avg. duration                 2.66666666667 switches 21
# Run 0 episode 7970 steps 24 cumreward 1.0 avg. duration                 2.6 switches 15
# Run 0 episode 7971 steps 5 cumreward 1.0 avg. duration                 2.66666666667 switches 3
# Run 0 episode 7972 steps 4 cumreward 1.0 avg. duration                 1.8 switches 5
# Run 0 episode 7973 steps 38 cumreward 1.0 avg. duration                 2.31034482759 switches 29
# Run 0 episode 7974 steps 33 cumreward 1.0 avg. duration                 2.4347826087 switches 23
# Run 0 episode 7975 steps 21 cumreward 1.0 avg. duration                 2.3125 switches 16
# Run 0 episode 7976 steps 10 cumreward 1.0 avg. duration                 2.66666666667 switches 6
# Run 0 episode 7977 steps 28 cumreward 1.0 avg. duration                 2.47368421053 switches 19
# Run 0 episode 7978 steps 30 cumreward 1.0 avg. duration                 2.5 switches 20
# Run 0 episode 7979 steps 14 cumreward 1.0 avg. duration                 2.16666666667 switches 12
# Run 0 episode 7980 steps 9 cumreward 1.0 avg. duration                 2.8 switches 5
# Run 0 episode 7981 steps 14 cumreward 1.0 avg. duration                 2.4 switches 10
# Run 0 episode 7982 steps 26 cumreward 1.0 avg. duration                 2.44444444444 switches 18
# Run 0 episode 7983 steps 0 cumreward 1.0 avg. duration                 1.0 switches 1
# Run 0 episode 7984 steps 19 cumreward 1.0 avg. duration                 2.46153846154 switches 13
# Run 0 episode 7985 steps 18 cumreward 1.0 avg. duration                 2.2 switches 15
# Run 0 episode 7986 steps 10 cumreward 1.0 avg. duration                 2.42857142857 switches 7
# Run 0 episode 7987 steps 4 cumreward 1.0 avg. duration                 2.0 switches 4
# Run 0 episode 7988 steps 7 cumreward 1.0 avg. duration                 2.4 switches 5
# Run 0 episode 7989 steps 35 cumreward 1.0 avg. duration                 2.20689655172 switches 29
# Run 0 episode 7990 steps 11 cumreward 1.0 avg. duration                 2.57142857143 switches 7
# Run 0 episode 7991 steps 17 cumreward 1.0 avg. duration                 2.88888888889 switches 9
# Run 0 episode 7992 steps 20 cumreward 1.0 avg. duration                 2.11111111111 switches 18
# Run 0 episode 7993 steps 9 cumreward 1.0 avg. duration                 2.5 switches 6
# Run 0 episode 7994 steps 12 cumreward 1.0 avg. duration                 2.57142857143 switches 7
# Run 0 episode 7995 steps 15 cumreward 1.0 avg. duration                 2.36363636364 switches 11
# Run 0 episode 7996 steps 10 cumreward 1.0 avg. duration                 2.0 switches 10
# Run 0 episode 7997 steps 13 cumreward 1.0 avg. duration                 2.2 switches 10
# Run 0 episode 7998 steps 11 cumreward 1.0 avg. duration                 2.1 switches 10
# Run 0 episode 7999 steps 17 cumreward 1.0 avg. duration                 2.0625 switches 16

# %%
import matplotlib.pyplot as plt

experiment = "experiment9"
save = True

plt.plot(xrange(nepisodes), np.mean(history[:, :, 0], axis=0))
plt.xlabel("Episodes")
plt.ylabel("Steps Per Episode")
if save:
    plt.savefig("plots/{}/learning_curve_nsteps.png".format(experiment))
plt.show()

plt.plot(xrange(nepisodes), np.mean(history[:, :, 1], axis=0))
plt.xlabel("Episodes")
plt.ylabel("Average Duration Of Options")
if save:
    plt.savefig("plots/{}/learning_curve_duration.png".format(experiment))
plt.show()

# %%
def visualize_policies(policies, goal, title, filename, threshold=0.9):
    fig, axs = plt.subplots(2, 2)
    
    for i in xrange(2):
        for j in xrange(2):
            policy = policies[2 * i + j]
            rooms_map = -2 * env.occupancy
            n_states = policy.weights.shape[0]
            n_actions = 4
            for s in xrange(n_states):
                max_prob = np.max(policy.pmf([s]))
                if max_prob > threshold:
                    rooms_map[env.tocell[s]] = np.argmax(policy.pmf([s]))
                else:
                    rooms_map[env.tocell[s]] = -1
            rooms_map[env.tocell[goal]] = 4
            im = axs[i, j].imshow(rooms_map)

    cbar = fig.colorbar(im, ax=axs.ravel().tolist())
    fig.suptitle(title)
    labels = ['wall', 'p < {}'.format(threshold), 'up', 'down', 'left', 'right', 'goal']
    cbar.ax.set_yticklabels(labels)
    if save:
        plt.savefig("plots/{}/{}.png".format(experiment, filename))
    plt.show()

""" 
policies_before = pickle.load(open("save/policies_before.p", "rb"))
policies_after = pickle.load(open("save/policies_after.p", "rb"))

visualize_policies(policies_before, 62, "Policies before goal change", "policies_before")
visualize_policies(policies_after, env.goal, "Policies after goal change", "policies_after")
"""

for i in xrange(1, change_count + 1):
    policies = pickle.load(open("save/policies_{}.p".format(i), "rb"))
    visualize_policies(policies, goals[i-1], "Policies after {} episodes".format(i * 1000),
                       "policies_{}".format(i))

# %%
def visualize_policy(policy, goal, title, filename, threshold=0.7):
    rooms_map = -2 * env.occupancy
    n_states = policy.weights.shape[0]
    n_actions = 4
    for s in xrange(n_states):
        max_prob = np.max(policy.value([s]))
        if max_prob > threshold:
            rooms_map[env.tocell[s]] = np.argmax(policy.value([s]))
        else:
            rooms_map[env.tocell[s]] = -1
    rooms_map[env.tocell[goal]] = 4
    
    plt.imshow(rooms_map)
    plt.title(title)
    cbar = plt.colorbar()
    labels = ['wall', 'p < {}'.format(threshold), 'top left option', 
              'top right option', 'bot left option', 
              'bot right option', 'goal']
    cbar.ax.set_yticklabels(labels)
    if save:
        plt.savefig("plots/{}/{}.png".format(experiment, filename))
    plt.show()
    
"""
policy_over_options_before = pickle.load(open("save/mainpolicy_before.p", "rb"))
policy_over_options_after = pickle.load(open("save/mainpolicy_after.p", "rb"))
    
visualize_policy(policy_over_options_before, 62, "Policy over options before goal change", "main_policy_before")
visualize_policy(policy_over_options_after, env.goal, "Policy over options after goal change", "main_policy_after")
"""

for i in xrange(1, change_count + 1):
    policy_over_options = pickle.load(open("save/mainpolicy_{}.p".format(i), "rb"))
    visualize_policy(policy_over_options, goals[i-1], 
                     "Policy over options after {} episodes".format(i * 1000), 
                     "main_policy_{}".format(i))

# %%
def visualize_terminations(terminations, goal, title, filename):
    fig, axs = plt.subplots(2, 2)
    
    for i in xrange(2):
        for j in xrange(2):
            termination = terminations[i + 2 * j]
            rooms_map = 0.4 * env.occupancy
            n_states = termination.weights.shape[0]
            for s in xrange(n_states):
                rooms_map[env.tocell[s]] = termination.pmf([s])
            rooms_map[env.tocell[goal]] = 1.0
            im = axs[i, j].imshow(rooms_map)
            
    fig.suptitle(title)
    cbar = fig.colorbar(im, ax=axs.ravel().tolist())
    if save:
        plt.savefig("plots/{}/{}.png".format(experiment, filename))
    plt.show()
    
"""
terminations_before = pickle.load(open("save/terminations_before.p", "rb"))
terminations_after = pickle.load(open("save/terminations_after.p", "rb"))

visualize_terminations(terminations_before, 62, "Terminations before goal change", "terminations_before")
visualize_terminations(terminations_after, env.goal, "Terminations after goal change", "terminations_after")
"""

for i in xrange(1, change_count + 1):
    terminations = pickle.load(open("save/terminations_{}.p".format(i), "rb"))
    visualize_terminations(terminations, goals[i-1], 
                           "Terminations after {} episodes".format(i * 1000), 
                           "terminations_{}".format(i))
